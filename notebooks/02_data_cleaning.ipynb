# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/processed/players_subset.csv')

print(f"Shape avant nettoyage: {df.shape}")
# Out:
# Shape avant nettoyage: (19239, 18)

# %%
print("Valeurs manquantes par colonne:")
print(df.isnull().sum())
# Out:
# Valeurs manquantes par colonne:
# short_name             0
# age                    0
# nationality_name       0
# overall                0
# potential              0
# club_name             61
# league_name           61
# player_positions       0
# value_eur             74
# wage_eur              61
# height_cm              0
# weight_kg              0
# pace                2132
# shooting            2132
# passing             2132
# dribbling           2132
# defending           2132
# physic              2132
# dtype: int64

# %%
# Remplacer les clubs/ligues manquants
df_clean['club_name'] = df_clean['club_name'].fillna('Free Agent')
df_clean['league_name'] = df_clean['league_name'].fillna('No League')

# %%
# Remplacer par 0 pour les joueurs sans valeur/salaire
df_clean['value_eur'] = df_clean['value_eur'].fillna(0)
df_clean['wage_eur'] = df_clean['wage_eur'].fillna(0)

# %%
# Remplacer par la médiane
physical_cols = ['height_cm', 'weight_kg']
for col in physical_cols:
    median = df_clean[col].median()
    df_clean[col] = df_clean[col].fillna(median)

# %%
stats_cols = ['pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']

for col in stats_cols:
    # Remplir par la médiane globale
    median = df_clean[col].median()
    df_clean[col] = df_clean[col].fillna(median)

# %%
print("Valeurs manquantes après nettoyage:")
print(df_clean.isnull().sum())
# Out:
# Valeurs manquantes après nettoyage:
# short_name          0
# age                 0
# nationality_name    0
# overall             0
# potential           0
# club_name           0
# league_name         0
# player_positions    0
# value_eur           0
# wage_eur            0
# height_cm           0
# weight_kg           0
# pace                0
# shooting            0
# passing             0
# dribbling           0
# defending           0
# physic              0
# dtype: int64

# %%
df_clean.to_csv('../data/processed/players_clean.csv', index=False)
print("Données nettoyées sauvegardées!")
# Out:
# Données nettoyées sauvegardées!
